# %%
# !pip install -U expertai-nlapi
# Out:
# Requirement already satisfied: expertai-nlapi in c:\users\hp\anaconda3\lib\site-packages (2.4.1)
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from expertai-nlapi) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests->expertai-nlapi) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests->expertai-nlapi) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from requests->expertai-nlapi) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests->expertai-nlapi) (1.26.9)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from expertai.nlapi.cloud.client import ExpertAiClient
import os

# %%
os.environ["EAI_USERNAME"] = 'khkiran01@gmail.com'
os.environ["EAI_PASSWORD"] = 'Meera@1977'

# %%
client = ExpertAiClient()

# %%
text = '''Michael Jordan was one of the best basketball players 
of all time. Scoring was Jordan's stand-out skill, but he still holds a defensive NBA record.''' 
language= 'en'

# %%
document = client.specific_resource_analysis(
    body={"document": {"text": text}}, 
    params={'language': language, 'resource': 'sentiment'
})

# %%
print (f'{"TERM":{20}} {"SENTIMENT":{4}}')    

for item in document.sentiment.items:
    if not item.lemma:
        group_lemma=[]
        for nested in item.items:
            group_lemma.append(nested.lemma)
        print (f'{str(group_lemma):{20}} {item.sentiment:{10}}')
    else:
        print (f'{item.lemma:{20}} {item.sentiment:{10}}')
# Out:
# TERM                 SENTIMENT
# ['but']                    -1.0
# basketball player           5.0
# scoring                     9.5
# skill                       3.5

# %%
output = client.specific_resource_analysis(
    body={"document": {"text": text}}, 
    params={'language': language, 'resource': 'relations'
})

# %%
print("Relations:");

for relation in output.relations:
    print(relation.verb.lemma, ":");
    for related in relation.related:
        print("\t", "(", related.relation, ")", related.lemma);
# Out:
# Relations:
# be :
# 	 ( sbj_who ) Michael Jordan
# be :
# 	 ( sbj_what ) scoring
# 	 ( is_what ) skill
# hold :
# 	 ( when ) still
# 	 ( sbj_who ) Michael Jordan
# 	 ( obj_what ) record

# %%
text = "We should hang John Doe"

detector = 'hate-speech'
language= 'en'

output = client.detection(body={"document": {"text": text}}, params={'detector': detector, 'language': language})

print("Categorization, list of categories (id and hierarchy):")

for category in output.categories:
    print(category.id_, category.hierarchy, sep="\t")

print("\nExtraction, list of records (record template: Hate_speech_detection):")

i = 1
for extraction in output.extractions:
    print("Record #{}:".format(i))
    for field in extraction.fields:
        print("{} = {}".format(field.name, field.value))
    i = i + 1
print(output.categories)
# Out:
# Categorization, list of categories (id and hierarchy):
# 3000	['Threat and Violence']
#
# Extraction, list of records (record template: Hate_speech_detection):
# Record #1:
# violence = We should hang John Doe
# target = individual
# [<expertai.nlapi.common.model.category.Category object at 0x000001C47C7709A0>]

# %%
pip install wikipedia
# Out:
# Requirement already satisfied: wikipedia in c:\users\hp\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\lib\site-packages (from wikipedia) (4.11.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from wikipedia) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.26.9)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\lib\site-packages (from beautifulsoup4->wikipedia) (2.3.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import wikipedia
 
wikipedia.summary("Arm company")
# Out:
# 'Arm is a British semiconductor and software design company based in Cambridge, England.\nIts primary business is in the design of ARM processors (CPUs). It also designs other chips, provides software development tools under the DS-5, RealView and Keil brands, and provides systems and platforms, system-on-a-chip (SoC) infrastructure and software. As a "holding" company, it also holds shares of other companies. Since 2016, it has been owned by Japanese conglomerate SoftBank Group.\nWhile ARM CPUs first appeared in the Acorn Archimedes, a desktop computer, today\'s systems include mostly embedded systems, including ARM CPUs used in virtually all smartphones. Systems such as iPhones and Android smartphones frequently include many chips, from many different providers, that include one or more licensed Arm cores, in addition to those in the main Arm-based processor. Arm\'s core designs are also used in chips that support all the most common network-related technologies.\nProcessors based on designs licensed from Arm, or designed by licensees of one of the ARM instruction set architectures, are used in all classes of computing devices. Arm has two lines of graphics processing units (GPUs), Mali, and the newer Immortalis (which includes hardware-based ray-tracing).Arm\'s main CPU competitors in servers include IBM, Intel and AMD.\nIntel competed with ARM-based chips in mobile, but Arm no longer has any competition in that space (however, vendors of actual ARM-based chips compete within that space). Arm\'s main GPU competitors include mobile GPUs from American and Japanese technology companies Imagination Technologies (PowerVR), Qualcomm (Adreno), and increasingly Nvidia, AMD, Samsung and Intel. While competing in GPUs, Qualcomm, Samsung and Nvidia all have combined their GPUs with Arm-licensed CPUs.\nArm had a primary listing on the London Stock Exchange and was a constituent of the FTSE 100 Index. It also had a secondary listing on NASDAQ. However Japanese conglomerate SoftBank Group made an agreed offer for Arm on 18 July 2016, subject to approval by Arm\'s shareholders, valuing the company at £24.3 billion. The transaction was completed on 5 September 2016.On 13 September 2020, it was announced that Nvidia would buy Arm from SoftBank for $40 billion, subject to regulatory approval, with the latter acquiring a 10% share in Nvidia.\nIn February 2022, the two companies reported that the deal had collapsed due to regulatory hurdles; SoftBank subsequently announced that it planned to float Arm on the stock market by 2023.'

# %%
l = wikipedia.page("Ford Motor").images
for i in l:
    k = i.find('logo')
    if k!=-1:
        print(i)
# Out:
# https://upload.wikimedia.org/wikipedia/commons/9/97/Ford_1957_logo.png
# https://upload.wikimedia.org/wikipedia/commons/3/39/Ford_logo1907.png
# https://upload.wikimedia.org/wikipedia/commons/d/d3/Ford_logo_1903.png
# https://upload.wikimedia.org/wikipedia/commons/f/f7/Ford_logo_1909.png
# https://upload.wikimedia.org/wikipedia/commons/7/70/Ford_logo_1911.png
# https://upload.wikimedia.org/wikipedia/commons/c/c5/Ford_logo_1912.png
# https://upload.wikimedia.org/wikipedia/commons/d/dd/Ford_logo_1927.png
# https://upload.wikimedia.org/wikipedia/commons/7/78/Ford_logo_1976.jpg
# https://upload.wikimedia.org/wikipedia/commons/3/3e/Ford_logo_flat.svg
# https://upload.wikimedia.org/wikipedia/commons/7/76/Ford_logo_oval_1912.png
# https://upload.wikimedia.org/wikipedia/commons/f/fa/Wikibooks-logo.svg
# https://upload.wikimedia.org/wikipedia/commons/f/fa/Wikiquote-logo.svg
# https://upload.wikimedia.org/wikipedia/commons/4/4c/Wikisource-logo.svg
# https://upload.wikimedia.org/wikipedia/en/4/4a/Commons-logo.svg

# %%
pip install StringIO
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement StringIO (from versions: none)
# ERROR: No matching distribution found for StringIO
#
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import IPython
url ='https://upload.wikimedia.org/wikipedia/commons/9/97/Ford_1957_logo.png'
IPython.display.Image(url, width = 250)

# %%
from expertai.nlapi.cloud.client import ExpertAiClient
client = ExpertAiClient()

text = "I experience a mix of conflicting emotions: the approach of the fateful date scares me, but at the same time I can't wait for it to arrive. I have moments of elation and others of pure panic, but I would say that I am mostly happy."
taxonomy = 'emotional-traits'
language= 'en'

output = client.classification(body={"document": {"text": text}}, params={'taxonomy': taxonomy, 'language': language})

print("Tab separated list of categories:")

for category in output.categories:
    print(category.hierarchy)
# Out:
# Tab separated list of categories:
# ['Group Apprehension', 'Fear']
# ['Group Delight', 'Happiness']
# ['Group Delight', 'Excitement']
# ['Group Delight', 'Joy']

# %%
pip install tweepy
# Out:
# Collecting tweepyNote: you may need to restart the kernel to use updated packages.
#   Downloading tweepy-4.11.0-py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.4/96.4 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\hp\anaconda3\lib\site-packages (from tweepy) (2.27.1)
# Collecting oauthlib<4,>=3.2.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      -------------------------------------- 151.7/151.7 kB 1.8 MB/s eta 0:00:00
# Collecting requests-oauthlib<2,>=1.2.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2021.10.8)
# Installing collected packages: oauthlib, requests-oauthlib, tweepy
# Successfully installed oauthlib-3.2.2 requests-oauthlib-1.3.1 tweepy-4.11.0
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tweepy
import re
import emoji
import nltk
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
pip install emoji
# Out:
# Collecting emojiNote: you may need to restart the kernel to use updated packages.
#   Downloading emoji-2.1.0.tar.gz (216 kB)
#      -------------------------------------- 216.6/216.6 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py): started
#   Building wheel for emoji (setup.py): finished with status 'done'
#   Created wheel for emoji: filename=emoji-2.1.0-py3-none-any.whl size=212392 sha256=4fdf7779027bb1078e9b28db6e4fd50b6266abef1065e6572eb0e5269091a001
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\b0\4a\c8\9c580a0ea94dea641b8023456a1b178a7e4509d992224ed4aa
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-2.1.0

# %%
my_bearer_token = "AAAAAAAAAAAAAAAAAAAAADnKawEAAAAArzcTtXJOw1Jx05SYlL%2F4J5%2F6Zv0%3Die1sm7TPVHtksmylWglnbmKUVNVzf7cEYBzeHDjTvB9aUggCQT"

# %%
 client = tweepy.Client(bearer_token=my_bearer_token)

# %%
response = client.search_recent_tweets("#ford",max_results=10)

# %%
tweets = response.data
print(len(tweets))
# Out:
# 10

# %%
tweets_texts = []

# %%
for tweet in tweets:  
    tweets_texts.append(tweet.text)
import pandas as pd
df = pd.DataFrame(data =  tweets_texts, columns=["Tweets"])

# %%
df
# Out:
#                                               Tweets
# 0  RT @nexta_tv: #American car manufacturer #Ford...
# 1  LED Car Slit Decoration Strip\n\n$ 13.90\n\n #...
# 2  Mit großen Ambitionen bündelten #VW und #Ford ...
# 3  How much can a GTX jacket take? Watch us put i...
# 4  RT @nexta_tv: #American car manufacturer #Ford...
# 5  アメリカのフォード、ロシア市場撤退を発表　ちなみに日本市場はとっくに撤退済み #Ford #...
# 6  https://t.co/hpDtSmngg3\n📷: ??? \n\n#OhSoRetro...
# 7  #PhotoDump \n\nActivity Wk 2 \n\n#GIANTSUP #SU...
# 8  🚗 FORD C-Max 1.0 EcoBoost 100 CV S&amp;S Plus ...
# 9  #Ford Motor Co on Wednesday reported a third-q...

# %%
def sentiment_overall(client, text):
    try:
        input_text = str(text)[0:10000]  # limit the input size
        document = client.specific_resource_analysis(
        body={"document": {"text": input_text}}, 
        params={'language': 'en', 'resource': 'sentiment'
       })
        return document.sentiment.overall
    except Exception as e: 
        print(str(e) +": " + str(text))

# %%
words = set(nltk.corpus.words.words())

# %%
def cleaner(tweet):
    tweet = re.sub("@[A-Za-z0-9]+","",tweet) #Remove @ sign
    tweet = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", tweet) #Remove http links
    tweet = " ".join(tweet.split())
    tweet = ''.join(c for c in tweet if c not in emoji.distinct_emoji_list(c)) #Remove Emojis
    tweet = tweet.replace("#", "").replace("_", " ") #Remove hashtag sign but keep the text
    tweet  = tweet.replace("\n"," ")
    tweet = re.sub(r'[^\w\s]', '', tweet)
    tweet = " ".join(w for w in nltk.wordpunct_tokenize(tweet)
                     if w.lower() in words or not w.isalpha())
    return tweet

# %%
df['text'] = df['Tweets'].map(lambda x: cleaner(x))

# %%
df
# Out:
#                                               Tweets  \
# 0  RT @nexta_tv: #American car manufacturer #Ford...
# 1  LED Car Slit Decoration Strip\n\n$ 13.90\n\n #...
# 2  Mit großen Ambitionen bündelten #VW und #Ford ...
# 3  How much can a GTX jacket take? Watch us put i...
# 4  RT @nexta_tv: #American car manufacturer #Ford...
# 5  アメリカのフォード、ロシア市場撤退を発表　ちなみに日本市場はとっくに撤退済み #Ford #...
# 6  https://t.co/hpDtSmngg3\n📷: ??? \n\n#OhSoRetro...
# 7  #PhotoDump \n\nActivity Wk 2 \n\n#GIANTSUP #SU...
# 8  🚗 FORD C-Max 1.0 EcoBoost 100 CV S&amp;S Plus ...
# 9  #Ford Motor Co on Wednesday reported a third-q...
#
#                                                 text overall
# 0  car manufacturer Ford Motor withdrawn from a j...    None
# 1  LED Car Slit Decoration Strip 1390 drive ford ...    None
# 2       Ford 2019 die um Nun die Partner Argo AI den    None
# 3  How much can a jacket take Watch us put it to ...    None
# 4  car manufacturer Ford Motor withdrawn from a j...    None
# 5                                      Ford corvette    None
# 6                                               Ford    None
# 7  Activity 2 SUP 2 TeamWork making summer fun se...    None
# 8  FORD 10 100 Plus FORD auto automotive market r...    None
# 9  Ford Motor on a net loss driven by its decisio...    None

# %%
df['overall'] = df['text'].apply(lambda review: sentiment_overall(client,text))

df.head()
# Out:
# 'Client' object has no attribute 'specific_resource_analysis': I experience a mix of conflicting emotions: the approach of the fateful date scares me, but at the same time I can't wait for it to arrive. I have moments of elation and others of pure panic, but I would say that I am mostly happy.
# 'Client' object has no attribute 'specific_resource_analysis': I experience a mix of conflicting emotions: the approach of the fateful date scares me, but at the same time I can't wait for it to arrive. I have moments of elation and others of pure panic, but I would say that I am mostly happy.
# 'Client' object has no attribute 'specific_resource_analysis': I experience a mix of conflicting emotions: the approach of the fateful date scares me, but at the same time I can't wait for it to arrive. I have moments of elation and others of pure panic, but I would say that I am mostly happy.
# 'Client' object has no attribute 'specific_resource_analysis': I experience a mix of conflicting emotions: the approach of the fateful date scares me, but at the same time I can't wait for it to arrive. I have moments of elation and others of pure panic, but I would say that I am mostly happy.
# 'Client' object has no attribute 'specific_resource_analysis': I experience a mix of conflicting emotions: the approach of the fateful date scares me, but at the same time I can't wait for it to arrive. I have moments of elation and others of pure panic, but I would say that I am mostly happy.
# 'Client' object has no attribute 'specific_resource_analysis': I experience a mix of conflicting emotions: the approach of the fateful date scares me, but at the same time I can't wait for it to arrive. I have moments of elation and others of pure panic, but I would say that I am mostly happy.
# 'Client' object has no attribute 'specific_resource_analysis': I experience a mix of conflicting emotions: the approach of the fateful date scares me, but at the same time I can't wait for it to arrive. I have moments of elation and others of pure panic, but I would say that I am mostly happy.
# 'Client' object has no attribute 'specific_resource_analysis': I experience a mix of conflicting emotions: the approach of the fateful date scares me, but at the same time I can't wait for it to arrive. I have moments of elation and others of pure panic, but I would say that I am mostly happy.
# 'Client' object has no attribute 'specific_resource_analysis': I experience a mix of conflicting emotions: the approach of the fateful date scares me, but at the same time I can't wait for it to arrive. I have moments of elation and others of pure panic, but I would say that I am mostly happy.
# 'Client' object has no attribute 'specific_resource_analysis': I experience a mix of conflicting emotions: the approach of the fateful date scares me, but at the same time I can't wait for it to arrive. I have moments of elation and others of pure panic, but I would say that I am mostly happy.
#                                               Tweets  \
# 0  RT @nexta_tv: #American car manufacturer #Ford...
# 1  LED Car Slit Decoration Strip\n\n$ 13.90\n\n #...
# 2  Mit großen Ambitionen bündelten #VW und #Ford ...
# 3  How much can a GTX jacket take? Watch us put i...
# 4  RT @nexta_tv: #American car manufacturer #Ford...
#
#                                                 text overall
# 0  car manufacturer Ford Motor withdrawn from a j...    None
# 1  LED Car Slit Decoration Strip 1390 drive ford ...    None
# 2       Ford 2019 die um Nun die Partner Argo AI den    None
# 3  How much can a jacket take Watch us put it to ...    None
# 4  car manufacturer Ford Motor withdrawn from a j...    None
